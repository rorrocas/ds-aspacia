# %%
### EJERCICIO 4

# %%
import seaborn as sns
import matplotlib.pyplot as plt

titanic = sns.load_dataset("titanic")

titanic.sample()
# Out:
#      survived  pclass   sex   age  sibsp  parch    fare embarked  class  who
# 455         1       3  male  29.0      0      0  7.8958        C  Third  man  \
#
#      adult_male deck embark_town alive  alone
# 455        True  NaN   Cherbourg   yes   True

# %% [markdown]
# ### 1. Confeccione un gráfico de barras para visualizar hombres y mujeres que han sobrevivido.

# %%
ax = sns.countplot(
    x="sex",
    data=titanic,
    hue="survived",
    palette=["red","blue"]
)
plt.title("Sobrevivencia por sexo")
plt.xlabel('Genero')
plt.ylabel('Numero de personas')
# Out:
# Text(0, 0.5, 'Numero de personas')

# %% [markdown]
# ### 2.- Cambiar el color del grafico

# %%
ax
plt.show()

# %% [markdown]
# ### 3.- Graficos agrupados

# %%
titanic_sobrevivientes = titanic[titanic["survived"]==1]

# %%
#POR CLASE
ax = sns.countplot(
    x="sex",
    data=titanic_sobrevivientes,
    hue="pclass",
    palette="colorblind"
)

# %%
# Por embarque
ax = sns.countplot(
    x="sex",
    data=titanic_sobrevivientes,
    hue="embarked",
    palette="colorblind"
)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,5))

sns.countplot(
    x="sex",
    data=titanic_sobrevivientes,
    hue="pclass",
    palette="colorblind", ax = axs[0]
)

sns.countplot(
    x="sex",
    data=titanic_sobrevivientes,
    hue="embarked",
    palette="colorblind", ax=axs[1]
)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>
