# %% [markdown]
# ### Ejercicio 2

# %%
import numpy as np
from scipy.stats import norm
import pandas as pd

# %%
def valor_z(start,end,step):

    z_scores = np.arange(start, end + step, step)
    # cumulative distribution function
    probabilities = norm.cdf(z_scores)
    df = pd.DataFrame({"z-score": z_scores, "probability": probabilities})
    return df

# %% [markdown]
# ### Caso 1: variable Aleatoria en Distribución normal

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Siendo
#
#     x: la probabilidad
#     u: media
#     d: desviacion estandar
#
# Entonces Z=(x-u)/d

# %% [markdown]
# Z = (u+3d-u)/d = (3d)/d = 3
#
# Z = 3
#
# P(Z<3) = 0.9987
#
# **P( u-3d < X < u+3d):**

# %%
X = (0.9987 - (1 - 0.9987))
print("La probabilidad de X es: ",round(X,4))
# Out:
# La probabilidad de X es:  0.9974

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Si
#
# u: 4
# d: 2
#
# Y sabemos que:
#
# P(4-a <= x <= 4+a) = 0.5934
#
# Por lo tanto:
#
# P(Z) - (1-P(Z)) = 0.5934
#
# Despejando:
#
# P(Z) = 0.7967
#
# Es decir:
#
# Z = 0.83
#
# Y reemplazamos en la tabla:
#
# (4+a-4)/2 = 0.83
#
# **El Valor de a es igual a 1.66**

# %%
(0.5934+1)/2
# Out:
# 0.7967

# %%
2*0.83
# Out:
# 1.66

# %%
1.66/2
# Out:
# 0.83

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### a) P(0 ≤ Z ≤ 1,25) =

# %%
df1 = valor_z(0,1.3,0.05)
df1.loc[df1["z-score"]== 1.25]
# Out:
#     z-score  probability
# 25     1.25      0.89435

# %%
df1.loc[df["z-score"]== 1.25].values[0][1] - 0.5
# Out:
# 0.39435022633314465

# %% [markdown]
# **R: La probabilidad es de 0.3944**

# %% [markdown]
# ### b) P(Z ≥ 1,25) =

# %%
df2 = valor_z(0,1.25,0.05)
df2.loc[df2["z-score"] == 1.25]
# Out:
#     z-score  probability
# 25     1.25      0.89435

# %%
1 - df2.loc[df2["z-score"] == 1.25].values[0][1]
# Out:
# 0.10564977366685535

# %% [markdown]
# **R: La probabilidad es de 0.1056**

# %% [markdown]
# ### c) P(Z ≤ −1,25) =

# %%
df3 = valor_z(0,1.25,0.05)
1 - df3.loc[df3["z-score"] == 1.25].values[0][1]
# Out:
# 0.10564977366685535

# %% [markdown]
# **R: La probabilidad es de 0.1056**

# %% [markdown]
# ### d) P(0 ≤ Z ≤ 1,33) =

# %%
df4 = valor_z(1.30, 1.35, 0.01)
df4.loc[df4["z-score"] == 1.33]
# Out:
#    z-score  probability
# 3     1.33     0.908241

# %%
df4.loc[df4["z-score"] == 1.33].values[0][1] - 0.5
# Out:
# 0.4082408643497193

# %% [markdown]
# **R: La probabilidad es de 0.4082**

# %% [markdown]
# ### e) P(Z ≥ 1,33) =

# %%
df5 = valor_z(1.30, 1.35, 0.01)
df5.loc[df5["z-score"] == 1.33]
# Out:
#    z-score  probability
# 3     1.33     0.908241

# %%
1 - df5.loc[df5["z-score"] == 1.33].values[0][1]
# Out:
# 0.09175913565028071

# %% [markdown]
# **R: La probabilidad es de 0.0918**

# %% [markdown]
# #### f) P(−1,33 ≤ Z ≤ 0) =

# %%
df6 = valor_z(1.30, 1.35, 0.01)
df6.loc[df6["z-score"] == 1.33]
# Out:
#    z-score  probability
# 3     1.33     0.908241

# %%
1 - (1-df6.loc[df6["z-score"] == 1.33].values[0][1]) - 0.5
# Out:
# 0.4082408643497193

# %% [markdown]
# **R: La probabilidad es de 0.4082**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Siendo:
#
# - n es el número de pruebas.
# - k es el número de éxitos.
# - p es la probabilidad de éxito.
# - q= 1-p es la probabilidad de fracaso.

# %% [markdown]
# n=12
# k=6
# p=0.5
# q=0.5
#
# p(x=6) = ((12!)/(6!(12-6)!))*((0.5)^(6))*((0.5)^(12-6))

# %%
factorial_12 = np.prod(np.arange(1, 12))
factorial_6 = np.prod(np.arange(1, 6))

# %%
potencia_1 = np.power(0.5, 6)

# %%
probabilidad = ((factorial_12)/(factorial_6*(factorial_6)))*(potencia_1)*(potencia_1)

# %%
print(f"La probabilidad de obtener 6 aciertos es de {probabilidad:.4f}")
# Out:
# La probabilidad de obtener 6 aciertos es de 0.6768

# %% [markdown]
# ### Preguntas Guia
# - Distribución de probabilidad
#
# **R: Es la funcion que describre la probabilidad de obtener un valor especifico en un conjunto de valores, al seleccionarlo de forma aleatoria.**
#
# - Variables Aleatorias(discretas y Continuas)
#
# **R: Las variables discretas son aquellas que dentro de una rango de valores existe un numero finito de valores mientras que las continuas toman valores infinitos en cualquier rango.**
#
# - Distribución Normal
#
# **R: Es un modelo probabilistico usado normalmente para interpretar sucesos de la naturaleza que tengan una tendencia central y un variabilidad simetrica.**
#
# - Distribución Binomial
#
# **R: Es un modelo para calcular las probabilidades de obtener cierta cantidad de aciertos cuando existen solo dos posibilidades como acierto y fracaso.**
