# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# importar dataset titanic desde seaborn
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# # 1.Confeccione un gráfico de barras para visualizar hombres y mujeres que han sobrevivido.

# %%
mascara_sobrevivientes = titanic['survived'] == 1
titanic_sobrevivientes = titanic[mascara_sobrevivientes]

ax = sns.countplot(
    x="sex",
    data=titanic,
    hue= 'survived',
    palette="colorblind"
)

# agregar titulo
plt.title("Distribución de pasajeros por sexo")

# agregar etiqueta de valores
plt.xlabel("Sexo")
plt.ylabel("Cantidad de pasajeros")
plt.show()

# %% [markdown]
# # 2. Cambiar el color del gráfico.

# %%
# cambiar color del grafico anterior
custom_palette = ["#FF0000", "#00FF00", "#0000FF", "#FFFF00"]
ax = sns.countplot(
    x="sex",
    data=titanic,
    hue= 'survived',
    palette=['red','blue']
)

# agregar titulo
plt.title("Distribución de pasajeros por sexo")

# agregar etiqueta de valores
plt.xlabel("Sexo")
plt.ylabel("Cantidad de pasajeros")
plt.show()

# %% [markdown]
# # 3. Gráfico barras agrupados

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

sns.countplot(
    x="sex",
    data=titanic_sobrevivientes,
    hue= 'pclass',
    palette="colorblind", ax = axs[0]
)
# agregar titulo
plt.title('Distribución de pasajeros sobrevivientes por sex y embarked')

sns.countplot(
    x="sex",
    data=titanic_sobrevivientes,
    hue= 'embarked',
    palette="colorblind", ax = axs[1]
)
plt.title('Distribución de pasajeros sobrevivientes por sex y pclass')
# Out:
# Text(0.5, 1.0, 'Distribución de pasajeros sobrevivientes por sex y pclass')
