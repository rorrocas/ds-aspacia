# %% [markdown]
# ### EJERCICIO 4

# %%
import seaborn as sns
import matplotlib.pyplot as plt

titanic = sns.load_dataset("titanic")

titanic.sample()
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked  class  who
# 614         0       3  male  35.0      0      0  8.05        S  Third  man  \
#
#      adult_male deck  embark_town alive  alone
# 614        True  NaN  Southampton    no   True

# %% [markdown]
# ### 1. Confeccione un gráfico de barras para visualizar hombres y mujeres que han sobrevivido.

# %%
ax = sns.countplot(
    x="sex",
    data=titanic,
    hue="survived"
    #palette=["red","blue"]
)
plt.title("Sobrevivencia por sexo")
plt.xlabel('Genero')
plt.ylabel('Numero de personas')
# Out:
# Text(0, 0.5, 'Numero de personas')

# %% [markdown]
# ### 2. Y cambia los colores

# %%
# cambiar color del grafico anterior
custom_palette = ["#FF0000", "#00FF00", "#0000FF", "#FFFF00"]
ax = sns.countplot(
    x="sex",
    data=titanic,
    hue= 'survived',
    palette=['red','blue']
)

# agregar titulo
plt.title("Distribución de pasajeros por sexo")

# agregar etiqueta de valores
plt.xlabel("Sexo")
plt.ylabel("Cantidad de pasajeros")
plt.show()

# %% [markdown]
# ### 3.- Graficos agrupados

# %%
titanic_sobrevivientes = titanic[titanic["survived"]==1]

# %%
#POR CLASE
ax = sns.countplot(
    x="sex",
    data=titanic_sobrevivientes,
    hue="pclass",
    palette="colorblind"
)

# %%
# Por embarque
ax = sns.countplot(
    x="sex",
    data=titanic_sobrevivientes,
    hue="embarked",
    palette="colorblind"
)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,5))

sns.countplot(
    x="sex",
    data=titanic_sobrevivientes,
    hue="pclass",
    palette="colorblind", ax = axs[0]
)

sns.countplot(
    x="sex",
    data=titanic_sobrevivientes,
    hue="embarked",
    palette="colorblind", ax=axs[1]
)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %% [markdown]
# # Tipos de gráficos para la librería Seaborn
#
# **R: histograma, dispersion, regresion , de barras, boxplot, de violin y heatmap**
